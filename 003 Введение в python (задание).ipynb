# %%
#vibo: Vitaliy Bocharov, telegram(@VitaliyBocharov)

# %% [markdown]
# ![](ods_stickers.jpg)

# %% [markdown]
# #### Открытый курс машинного обучения (ведет - Петр Ермаков)
# ## 003 Введение в python (задание)

# %%
#vibo: 003 Введение в python https://youtu.be/rWxD7vZdldY

# %% [markdown]
# ### Вопрос 1.

# %% [markdown]
# Написать код, который вычисляет сумму всех чисел, удовлетворяющих следующие условия:
# - положительные целые числа от 1 до 1_000_000_002 (один миллиард два) включительно
# - которые нацело (без остатка) делятся на 3 (пример: 3, 6, 9, ...)
# - и которые не заканчиваются на 4 и 7 (пример заканчивающихся на 4 и 7: 24, 27, 54, 57 ...)
#
# Результат суммы ввести в поле ниже.
# В поле нужно ввести только число, являющееся ответом, без пробелов и других символов.

# %% [markdown]
# #### Подготовка

# %% [markdown]
# ##### Решение-1: brut force - 2min 45s

# %%
# %%time
#vibo: вариант 1 brut force

#vibo: искомое значение a
a = 0
#vibo: проходим циклом по значениям от 1 до 1 000 000 003 (последнее значение не включается)
for i in range(1, 1000000003):
    #print('i=', i)
    #vibo: три условия (целочисленное даление без остатка на 3;
    #vibo: остаток от целочисленного деления на 10 не должен равняться 4 и 7)
    if i%3==0 and i%10!=4 and i%10!=7:
    #vibo: или так
    #if i%3==0 and not (i%10==4 or i%10==7):
        #print('i=', i)
        #vibo: сумма нарaстающим итогом
        a +=i
        #print('a=', a)
        #print('***')
print('Ответ:', a)
# Out:
# Ответ: 133333334466666672
# CPU times: user 2min 45s, sys: 17 ms, total: 2min 45s
# Wall time: 2min 45s

# %% [markdown]
# ##### Решение-2: brut force + генератор - 1min 20s

# %%
# %%time
#vibo: вариант 2 brut force с генератором чисел кратных трем
a = 0
#vibo: задаем генератор чисел кратных трем
#vibo: сразу значительно сокращаем количество цифр перебора
for i in range(3, 1000000003, 3):
    #vibo: уже проверяем только по двум условиям
    if i%10!=4 and i%10!=7:
        a +=i
print('Ответ:', a)
# Out:
# Ответ: 133333334466666672
# CPU times: user 1min 19s, sys: 72.6 ms, total: 1min 19s
# Wall time: 1min 20s

# %% [markdown]
# ##### Решение-: вычитание списков - out of memory

# %%
#vibo: только списками вычислить не получается, нехватка памяти
#vibo: пришлось уменьшить значение до 1003, не подходит
a3 = [i for i in range(3, 1003, 3)]
print(a3)
a24 = [i for i in range(24, 1003, 30)]
print(a24)
a27 = [i for i in range(27, 1003, 30)]
print(a27)
#vibo: избавляемся от ненужных значений
#vibo: преобразование в set оставляет только уникальные значения
a_tot = list(set(a3) - set(a24) - set(a27))
print(a_tot)
#vibo: для суммирования нужно от set перейти снова к list
print(sum(a_tot))
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 
, 732, 735, 738, 741, 750, 753, 756, 759, 762, 765, 768, 771, 780, 783, 786, 789, 792, 795, 798, 801, 810, 813, 816, 819, 822, 825, 828, 831, 840, 843, 846, 849, 852, 855, 858, 861, 870, 873, 876, 879, 882, 885, 888, 891, 900, 903, 906, 909, 912, 915, 918, 921, 930, 933, 936, 939, 942, 945, 948, 951, 960, 963, 966, 969, 972, 975, 978, 981, 990, 993, 996, 999, 1002]
# 134472

# %% [markdown]
# ##### Решение-3: списки + матидея - 23.1 s

# %%
# %%time
#vibo: вариант 3 списки и идея арифметической прогрессии

#vibo: задаем список кратный трем, суммируем члены
v3_s_ap1 = sum(i for i in range(3, 1000000003, 3))
print(v3_s_ap1)

#vibo: задаем список 24, 54, и т.д. с шагом +30, суммируем члены
v3_s_ap2 = sum(i for i in range(24, 1000000003, 30))
print(v3_s_ap2)

#vibo: задаем список 27, 57 и т.д. с шагом +30, суммируем члены
v3_s_ap3 = sum(i for i in range(27, 1000000003, 30))
print(v3_s_ap3)

#vibo: из суммы членов первой арифметической прогрессии вычитаем суммы двух других
print('Ответ', v3_s_ap1 - v3_s_ap2 - v3_s_ap3)
# Out:
# 166666667833333335
# 16666666633333332
# 16666666733333331
# Ответ 133333334466666672
# CPU times: user 23 s, sys: 3.28 ms, total: 23 s
# Wall time: 23.1 s

# %% [markdown]
# ##### Решение-4: аналитическое решение - 2.89 ms

# %%
# %%time
#vibo: вараиант 4 аналитическое решение (арифметическая прогрессия)

#vibo: последние члены арифметической прогрессии 24, 54 +30
ap2_an = list((i for i in range(24, 1000000003, 30)))[-1]
print(ap2_an)
#vibo: последние члены арифметической прогрессии 27, 57 +30
ap3_an = list((i for i in range(27, 1000000003, 30)))[-1]
print(ap3_an)
# Out:
# 999999984
# 999999987
# CPU times: user 4.4 s, sys: 1.19 s, total: 5.59 s
# Wall time: 5.7 s

# %%
# %%time
#vibo: сумма членов арифметической прогрессии кратных 3
#vibo: первый член
ap1_a1 = 3
#vibo: последний член
ap1_an = 1000000002
#vibo: количество членов (1000000002/3)
ap1_n = 333333334
#vibo: сумма членов армифметической прогрессии
v4_s_ap1 = (ap1_a1 + ap1_an) * ap1_n / 2
print(v4_s_ap1)
print('Проверка v3_s_ap1 - v4_s_ap1 =', v3_s_ap1 - v4_s_ap1)

#vibo: cумма членов рифметической прогрессии 24, 54 (шаг +30)
#vibo: первый член
ap2_a1 = 24
#vibo: последний член
ap2_an = 999999984
#vibo: количество членов арифметической прогрессии
ap2_n = ((ap2_an - ap2_a1)/30) + 1
#vibo: сумма членов армифметической прогрессии
v4_s_ap2 = (ap2_a1 + ap2_an) * ap2_n / 2
print(v4_s_ap2)
print('Проверка v3_s_ap2 - v4_s_ap2 =', v3_s_ap2 - v4_s_ap2)

#vibo: сумма членов арифметической прогрессии 27, 57 (шаг +30)
#vibo: первый член
ap3_a1 = 27
#vibo: последний член
ap3_an = 999999987
#vibo: количество членов арифметической прогрессии
ap3_n = ((ap3_an - ap3_a1)/30) + 1
#vibo: сумма членов армифметической прогрессии
v4_s_ap3 = (ap3_a1 + ap3_an) * ap3_n / 2
print(v4_s_ap3)
print('Проверка v3_s_ap3 - v4_s_ap3 =', v3_s_ap3 - v4_s_ap3)

print(v4_s_ap1 - v4_s_ap2 - v4_s_ap3)
print('Проверка:', (v4_s_ap1 - v4_s_ap2 - v4_s_ap3) - (v3_s_ap1 - v3_s_ap2 - v3_s_ap3))

print('Ответ:', int(v4_s_ap1 - v4_s_ap2 - v4_s_ap3))
# Out:
# 1.6666666783333334e+17
# Проверка v3_s_ap1 - v4_s_ap1 = 0.0
# 1.6666666633333332e+16
# Проверка v3_s_ap2 - v4_s_ap2 = 0.0
# 1.6666666733333332e+16
# Проверка v3_s_ap3 - v4_s_ap3 = 0.0
# 1.3333333446666667e+17
# Проверка: 0.0
# Ответ: 133333334466666672
# CPU times: user 3.97 ms, sys: 0 ns, total: 3.97 ms
# Wall time: 2.89 ms

# %% [markdown]
# #### Итоговое решение

# %%
# %%time
#vibo: вариант 3 списки и идея арифметической прогрессии

#vibo: задаем список кратный трем, суммируем члены
v3_s_ap1 = sum(i for i in range(3, 1000000003, 3))
print(v3_s_ap1)

#vibo: задаем список 24, 54, и т.д. с шагом +30, суммируем члены
v3_s_ap2 = sum(i for i in range(24, 1000000003, 30))
print(v3_s_ap2)

#vibo: задаем список 27, 57 и т.д. с шагом +30, суммируем члены
v3_s_ap3 = sum(i for i in range(27, 1000000003, 30))
print(v3_s_ap3)

#vibo: из суммы членов первой арифметической прогрессии вычитаем суммы двух других
print('Ответ', v3_s_ap1 - v3_s_ap2 - v3_s_ap3)
# Out:
# 166666667833333335
# 16666666633333332
# 16666666733333331
# Ответ 133333334466666672
# CPU times: user 24 s, sys: 8.05 ms, total: 24 s
# Wall time: 24.2 s

# %% [markdown]
# ##### Код для ods.ai

# %% [markdown]
# Сюда скопируйте и отправьте код, который решает задачу пунктом выше

# %%
v3_s_ap1 = sum(i for i in range(3, 1000000003, 3))
v3_s_ap2 = sum(i for i in range(24, 1000000003, 30))
v3_s_ap3 = sum(i for i in range(27, 1000000003, 30))
print(v3_s_ap1 - v3_s_ap2 - v3_s_ap3)
# Out:
# 133333334466666672

# %% [markdown]
# ### Вопрос 2.

# %% [markdown]
# На вход поступает текстовый файл из 3-х тысяч строк
#
# Формат файла:
#     "арифметическая операция"    "целое число #1"    "целое число #2"
# Разделитель - 4 пробела
#
#
# Нужно подготовить текстовый файл из 1 строки.
# Строка содержит набор из 3-х тысяч чисел, разделенных запятой.
# После последнего числа запятая не ставится.
# каждое число - результат операции:
#     "результирующее целое число" = "целое число #1" применить "арифметическая операция" "целое число #2"

# %% [markdown]
# #### Подготовка

# %%
#vibo: импортируем библиотеку
import operator
result = {'+': operator.add, '-': operator.sub, '*': operator.mul, '//': operator.floordiv, '%': operator.mod, '**': operator.pow}

# %%
#vibo: делаем проверку
a = 3
b = 2
print(result['+'](a, b), '=', a + b)
print(result['-'](a, b), '=', a - b)
print(result['*'](a, b), '=', a * b)
print(result['//'](a, b), '=', a // b)
print(result['%'](a, b), '=', a % b)
print(result['**'](a, b), '=', a ** b)
# Out:
# 5 = 5
# 1 = 1
# 6 = 6
# 1 = 1
# 1 = 1
# 9 = 9

# %%
#vibo: на вход поступает строка
one_line = str('+    2    8')
#vibo: разделитель - четыре пробела
line_split = one_line.split('    ')
#vibo: проверяем
print(line_split)
#vibo: итоговая формула, проверяем
result[line_split[0]](int(line_split[1]),int(line_split[2]))
# Out:
# ['+', '2', '8']
# 10

# %%
#vibo: импортируем библиотеку
import operator
result = {'+': operator.add, '-': operator.sub, '*': operator.mul, '//': operator.floordiv, '%': operator.mod, '**': operator.pow}
big_line = []
for one_line in open('test_input_file_1.txt', 'r').readlines():
    line_split = one_line.split('    ')
    one_answer = result[line_split[0]](int(line_split[1]),int(line_split[2]))
    big_line.append(one_answer)
print(one_answer)
# Out:
# 508021860739623365322188197652216501772434524836001

# %%
#vibo: проверяем элементы списка
print(type(big_line))
print(big_line[0:10])
# Out:
# <class 'list'>
# [-1551, 0, -49826439, 318, 68592064, -366, -1020, 1, 0, 5927]

# %%
#vibo: преобразуем каждый элемент list в str и склеиваем join
big_str = ",".join([str(_) for _ in big_line])

# %%
#vibo: посмотрим, что получилось
print(type(big_str))
print(big_str)
# Out:
# <class 'str'>
# -1551,0,-49826439,318,68592064,-366,-1020,1,0,5927,14076019706120526112710656,4007885,349,-6084,1,5510,7342,-2698,1,372,-541,30431804,15694,59604644775390625,16835031,0,793714773254144,11026381951494519544538618432455883057857446928297348599765724730351258025260434645737117862538664702513136890902785802597870420145626388338001806739753231769,-52699853,1065,451,0,2623,0,8470329472543003390683225006796419620513916015625,2210,6149,-12142,2417851639229258349412352,1459,0,0,1286,70,2787015,-2848,-10033,154742504910672534362390528,0,-13255,12012,-16279,6253,-1363,0,-3710,981,6092,23605998,-9460,59768263894155949306790119265585619217025149412430681649,-2717526,6344,1,380,7,69690070456714036934135773061833984669532003071343585548161,13620860,37,7597,-7350,-13701,610,7922816251426433759354395033600000000000000000000000000000000,564,1,936,0,22,7425803930678705826362025654596757993811865030054903808,12167,-12139,18661,-32220474,-7403,-1340,-9376307,9369,1792,983,8736651,547150826329050817707232047731001563323399357039042635859624984576,231,10648,3597600662921626628600135655553196556866168975830078125,1,-9170,9313728,-2909,1391,0,-2099,-5683927,-12647,1651,1579188,215671155821681003462656,2643,1313820,9671406556917033397649408,999,0,-9568,-9449580,-10496,2465,260,14008,379749833583241,529144398052420314716929933900838757437386767361,1,58163090,13552527156068805425093160010874271392822265625,41,576,2579,5302,-14064,35032,3919,1281,21904765,-45498856,818,3498,0,-2862600,379185422831233928797765495057459006009375879956409520007340289427766231081300783149624649056256,-76032840,3142,-28302916,-182,2811,185,945,35633247,4527,1576,2756,14296,11900,-2166,2304,0,35,9310566,999356547346805156075552524294177648535563,-5458,1234,3238271571766698647339965484615566548083418922349006074474896818176,5086,37929227194915558802161,2019033315579916446064959983973324467492312698573142949239105755973419008,1,-7315,470184984576,516116642098754030145043477561344,1758,437905770101505334663665494778098791025081856836411178674083838715559713339331437964574433863162994384765625,3753,-13612,-67152,310,512,695,2955545,23239386,6554,1577753820348458066150427430000000000000000000000000000000,1595,1311,9,17594220,210,12636,2024891623976437135118764865774783290467102632746078437376,0,1776592919961297100543276866939850151538848876953125,1753,-3533,15576,1,2178,5079254942691100593136855621137750255659237592448086481329148082980363356946249741767587983359321090826701361999913386264331782624506076395995136,17212,169,-2742950,39260655,17530,1258,6211,1,249358730666939096153411411739203931263313801,4292,35937776,0,0,2117,14084681287183985758907378814685465267498041327756731239439202626583872382284333056,2411865032257058775038130904326570702735480588505508642005857943,-8717632,34295718,-5786,22743792394229783703324968302948048914802297906725751125690494748022168763393663766122202934319824761844480012849410006555553109314693743185383201,2876,-13653635,1000,2908,5,-22948884,6434,-1869583,59319,10047,-2357,16815125390625,308,0,3686,19487171,6864377172744689378196133203444067624537070830997366604446306636401,-14195,-30,442,3991126307559121003502065461544836026149595571888353087406043254308491754223554789595852224446896829603935680252692924700146054728121455386558464,-3032,0,1099,5709,42366240,-3868,0,-4079,-6569150,37778931862957161709568,-9509,4263,2646,53192922805113395216521790854532783920263403514829117187286364944702512945453447406447271436978772068980418968613005773824790251228084975544249980198426812101774039476481485266623660032,1,-18094,0,189981351074408073951701600114073766275751709344935895421845768145404585904922034352160768,3357,4477456,178,425220839059883623744333365029331731745680194453438028952946488279204632909635819260074640624225139617919921875,1,353,0,0,5099,172,31,182,-2492,8566334697992967007470625843214916637570443887069350872071897312001270514603864367,98,0,4271,-6659,2,2803621,-8441,14592,-3629,0,5,3054,6077,356811923176489970264571492362373784095686656,2,0, ...

# %%
#vibo: записываем ответ в файл
with open('v_test_output_file_1.txt', 'w') as f:
    f.write(big_str)

# %%
#vibo: делеаем проверку
#vibo: читаем данные тестового аутпута
test_output_file_1 = open ('test_output_file_1.txt', 'r')
test_output_object_1 = test_output_file_1.read()
#vibo: читаем данные моего аутпута
v_test_output_file_1 = open ('v_test_output_file_1.txt', 'r')
v_test_output_object_1 = v_test_output_file_1.read()
#vibo: сравнение двух str
test_output_object_1 == v_test_output_object_1
# Out:
# True

# %% [markdown]
# #### Итоговое решение

# %%
#vibo: теперь тоже самое для заданного файла

#vibo: импортируем библиотеку
import operator
result = {'+': operator.add, '-': operator.sub, '*': operator.mul, '//': operator.floordiv, '%': operator.mod, '**': operator.pow}
big_line = []
for one_line in open('input_file.txt', 'r').readlines():
    line_split = one_line.split('    ')
    one_answer = result[line_split[0]](int(line_split[1]),int(line_split[2]))
    big_line.append(one_answer)

#vibo: преобразуем каждый элемент list в str и склеиваем join
big_str = ",".join([str(_) for _ in big_line])

#vibo: записываем ответ в файл
with open('v_output_file_1.txt', 'w') as f:
    f.write(big_str)

# %% [markdown]
# ##### Код для ods.ai

# %% [markdown]
# Сюда скопируйте и отправьте код, который решает задачу пунктом выше

# %%
import operator
result = {'+': operator.add, '-': operator.sub, '*': operator.mul, '//': operator.floordiv, '%': operator.mod, '**': operator.pow}
big_line = []
for one_line in open('input_file.txt', 'r').readlines():
    line_split = one_line.split('    ')
    one_answer = result[line_split[0]](int(line_split[1]),int(line_split[2]))
    big_line.append(one_answer)
big_str = ",".join([str(_) for _ in big_line])
with open('v_output_file_1.txt', 'w') as f:
    f.write(big_str)

# %% [markdown]
# ### Вопрос 3.

# %% [markdown]
# На вход поступает два текстовый файл из 3-х тысяч строк каждый.
#
# Первый файл содержит строки текста.
# Второй файл содержит строки из двух целых неотрицательных чисел.
#
# Первое число в строке всегда меньше или равно второму.
# Числа всегда меньше длины соответствующей строки первого файла.
# Соответствующей - это значит 1-ая строка из 1-го файла соответствует 1-ой строке из 2-го файла, а 123-я строка из 1-го файла соответствует 123-ей строке из 2-го файла.
#
# Подготовить выходной файл, который состоит из подстрок 1-го входного файла. Подстроки разделены пробелами. Какие брать подстроки - написано во втором файле. В конце файла пробела нет.

# %% [markdown]
# #### Подготовка

# %%
#vibo: на вход подается строка из файла 1
one_str_f1 = 'XESADKaIFRctwwLIptQeRaKdDiNFdIHbvkanQUhtPGRIXNprSjXSagoRUzAThRVSHNxksFZkJmZUZYNLVuVumbEJynIBSCcjIXoBe'
print(type(one_str_f1))
#vibo: преобразуем строку к листу для индексации по данным из файла 2
one_list_f1 = list(one_str_f1)
#vibo: индексация по символам от 39 до 46 включая оба (правый край не входит, поэтому +1 индекс)
print(one_list[39:46+1])
#vibo: склеиваем результат слайса первой строки
join_answer_1 = "".join([str(_) for _ in one_list[39:46+1]])
print(join_answer_1)
# Out:
# <class 'str'>
# ['t', 'P', 'G', 'R', 'I', 'X', 'N', 'p']
# tPGRIXNp

# %%
#vibo: на вход подается строка и из файла 2
one_str_f2 = '39 46'
print(type(one_str_f2))
#vibo: разрезаем по пробелу
one_str_f2_split = one_str_f2.split(' ')
print(one_str_f2_split)
#vibo: после метода join получили лист
print(type(one_str_f2_split))
#vibo: индексация НЕ ЗАБЫТЬ ПРО +1
print(one_str_f2_split[0])
print(one_str_f2_split[1])
# Out:
# <class 'str'>
# ['39', '46']
# <class 'list'>
# 39
# 46

# %%
#vibo: теперь все тожже, но с индексацией
#vibo: на вход подается строка из файла 1
one_str_f1 = 'XESADKaIFRctwwLIptQeRaKdDiNFdIHbvkanQUhtPGRIXNprSjXSagoRUzAThRVSHNxksFZkJmZUZYNLVuVumbEJynIBSCcjIXoBe'
#vibo: преобразуем строку к листу для индексации по данным из файла 2
one_list_f1 = list(one_str_f1)

#vibo: на вход подается строка и из файла 2
one_str_f2 = '39 46'
#vibo: разрезаем по пробелу
one_str_f2_split = one_str_f2.split(' ')

#vibo: склеиваем результат слайса первой строки (правая граница +1)
join_answer_1 = "".join([str(_) for _ in one_list_f1[int(one_str_f2_split[0]):int(one_str_f2_split[1])+1]])
print(join_answer_1)
# Out:
# tPGRIXNp

# %%
#vibo: создаем пустой лист для записи результатов
big_line_2 = []
#vibo: на вход подается строка из файла 1 и файла 2, используем zip
for one_str_f1, one_str_f2 in zip(open('test_import_file_2_1.txt', 'r').readlines(), open('test_import_file_2_2.txt', 'r').readlines()):
    #vibo: преобразуем строку к листу для индексации по данным из файла 2
    one_list_f1 = list(one_str_f1)
    #vibo: разрезаем по пробелу cтроку из файла 2, чтобы взять индексы
    one_str_f2_split = one_str_f2.split(' ')
    #vibo: склеиваем результат слайса строки (правая граница +1)
    join_answer = "".join([str(_) for _ in one_list_f1[int(one_str_f2_split[0]):int(one_str_f2_split[1])+1]])
    #vibo: добавляем результат строки в лист
    big_line_2.append(join_answer)

#vibo: результат склеиваем в одну строку по условию задачи
big_str_2 = " ".join([str(_) for _ in big_line_2])
#vibo: записываем результат в файл
with open('v_test_output_file_2.txt', 'w') as f:
    f.write(big_str_2)

# %%
#vibo: делеаем проверку
#vibo: читаем данные тестового аутпута
test_output_file_2 = open ('test_output_file_2.txt', 'r')
test_output_object_2 = test_output_file_2.read()
#vibo: читаем данные моего аутпута
v_test_output_file_2 = open ('v_test_output_file_2.txt', 'r')
v_test_output_object_2 = v_test_output_file_2.read()
#vibo: сравнение двух str
test_output_object_2 == v_test_output_object_2
# Out:
# True

# %% [markdown]
# #### Итоговое решение

# %%
#vibo: теперь тоже самое для загрузки на платформу
#vibo: создаем пустой лист для записи результатов
big_line_2 = []
#vibo: на вход подается строка из файла 1 и файла 2, используем zip
for one_str_f1, one_str_f2 in zip(open('import_file_2_1.txt', 'r').readlines(), open('import_file_2_2.txt', 'r').readlines()):
    #vibo: преобразуем строку к листу для индексации по данным из файла 2
    one_list_f1 = list(one_str_f1)
    #vibo: разрезаем по пробелу cтроку из файла 2, чтобы взять индексы
    one_str_f2_split = one_str_f2.split(' ')
    #vibo: склеиваем результат слайса строки (правая граница +1)
    join_answer = "".join([str(_) for _ in one_list_f1[int(one_str_f2_split[0]):int(one_str_f2_split[1])+1]])
    #vibo: добавляем результат строки в лист
    big_line_2.append(join_answer)

#vibo: результат склеиваем в одну строку по условию задачи
big_str_2 = " ".join([str(_) for _ in big_line_2])
#vibo: записываем результат в файл
with open('v_output_file_2.txt', 'w') as f:
    f.write(big_str_2)

# %% [markdown]
# ##### Код для ods.ai

# %% [markdown]
# Сюда скопируйте и отправьте код, который решает задачу пунктом выше

# %%
big_line_2 = []
for one_str_f1, one_str_f2 in zip(open('import_file_2_1.txt', 'r').readlines(), open('import_file_2_2.txt', 'r').readlines()):
    one_list_f1 = list(one_str_f1)
    one_str_f2_split = one_str_f2.split(' ')
    join_answer = "".join([str(_) for _ in one_list_f1[int(one_str_f2_split[0]):int(one_str_f2_split[1])+1]])
    big_line_2.append(join_answer)

big_str_2 = " ".join([str(_) for _ in big_line_2])
with open('v_output_file_2.txt', 'w') as f:
    f.write(big_str_2)

# %% [markdown]
# ### Вопрос 4.

# %% [markdown]
# На вход поступает строка.
# В ней хранится набор химических символов (He, O, H, Mg, Fe, ...). Без пробелов.
# Нужно расшифровать химические символы в название химических элементов.
# Для удобства, прилагается json файл, который ставит в соответствие химическому символу его химическое название.
# Как прочитать этот файл в словарь python (dict):
#
# periodic_table = json.load(open('periodic_table.json'))
#
# Обратите внимание, что, например, "Bi" - это "Висмут", а не "БорЙод".
# **То есть регистр (заглавные или прописные) букв имеет значение.**

# %% [markdown]
# #### Подготовка

# %%
#vibo: импортирируем
import json
periodic_table = json.load(open('periodic_table.json'))

# %%
print(type(periodic_table))
print(periodic_table)
# Out:
# <class 'dict'>
# {'Ac': 'Актиний', 'Ag': 'Серебро', 'Al': 'Алюминий', 'Am': 'Америций', 'Ar': 'Аргон', 'As': 'Мышьяк', 'At': 'Астат', 'Au': 'Золото', 'B': 'Бор', 'Ba': 'Барий', 'Be': 'Бериллий', 'Bh': 'Борий', 'Bi': 'Висмут', 'Bk': 'Берклий', 'Br': 'Бром', 'C': 'Углерод', 'Ca': 'Кальций', 'Cd': 'Кадмий', 'Ce': 'Церий', 'Cf': 'Калифорний', 'Cl': 'Хлор', 'Cm': 'Кюрий', 'Cn': 'Коперниций', 'Co': 'Кобальт', 'Cr': 'Хром', 'Cs': 'Цезий', 'Cu': 'Медь', 'Db': 'Дубний', 'Ds': 'Дармштадтий', 'Dy': 'Диспрозий', 'Er': 'Эрбий', 'Es': 'Эйнштейний', 'Eu': 'Европий', 'F': 'Фтор', 'Fe': 'Железо', 'Fl': 'Флеровий', 'Fm': 'Фермий', 'Fr': 'Франций', 'Ga': 'Галий', 'Gd': 'Гадолиний', 'Ge': 'Германий', 'H': 'Водород', 'He': 'Гелий', 'Hf': 'Гафний', 'Hg': 'Ртуть', 'Ho': 'Гольмий', 'Hs': 'Хассий', 'I': 'Йод', 'In': 'Индий', 'Ir': 'Иридий', 'K': 'Калий', 'Kr': 'Криптон', 'La': 'Лантан', 'Li': 'Литий', 'Lr': 'Лоуренсий', 'Lu': 'Лютеций', 'Lv': 'Ливерморий', 'Mc': 'Московий', 'Md': 'Менделевий', 'Mg': 'Магний', 'Mn': 'Марганец', 'Mo': 'Молибден', 'Mt': 'Мейтнерий', 'N': 'Азот', 'Na': 'Натрий', 'Nb': 'Ниобий', 'Nd': 'Неодим', 'Ne': 'Неон', 'Nh': 'Нихоний', 'Ni': 'Никель', 'No': 'Нобелий', 'Np': 'Нептуний', 'O': 'Кислород', 'Ods': 'Пасхалочка', 'Og': 'Оганесон', 'Os': 'Осмий', 'P': 'Фосфор', 'Pa': 'Протактиний', 'Pb': 'Свинец', 'Pd': 'Палладий', 'Pm': 'Прометий', 'Po': 'Полоний', 'Pr': 'Празеодим', 'Pt': 'Платина', 'Pu': 'Плутоний', 'Ra': 'Радий', 'Rb': 'Рубидий', 'Re': 'Рений', 'Rf': 'Разерфордий', 'Rg': 'Ренгений', 'Rh': 'Родий', 'Rn': 'Радон', 'Ru': 'Рутений', 'S': 'Сера', 'Sb': 'Сурьма', 'Sc': 'Скандий', 'Se': 'Селен', 'Sg': 'Сиборгий', 'Si': 'Кремний', 'Sm': 'Самарий', 'Sn': 'Олово', 'Sr': 'Стронций', 'Ta': 'Тантал', 'Tb': 'Тербий', 'Tc': 'Технеций', 'Te': 'Теллур', 'Th': 'Торий', 'Ti': 'Титан', 'Tl': 'Таллий', 'Tm': 'Тулий', 'Ts': 'Теннессин', 'U': 'Уран', 'Uue': 'Унуненний', 'V': 'Ванадий', 'W': 'Вольфрам', 'Xe': 'Ксенон', 'Y': 'Иттрий', 'Yb': 'Иттербий', 'Zn': 'Цинк', 'Zr': 'Цирконий'}

# %%
#vibo: разбираем пример
import re
example_4 = 'NOTiFICaTiiiiiiON'
example_4 = re.findall(r'[A-Z]?[^A-Z]*', example_4)

example_4 = example_4[:int(len(example_4))-1]
print(example_4)
# Out:
# ['N', 'O', 'Ti', 'F', 'I', 'Ca', 'Tiiiiii', 'O', 'N']

# %%
#vibo: загружаем библиотеки
import re
import json

#vibo: читаем данные из заданного файла
import_file_3 = open ('import_file_3.txt', 'r')
import_object_3 = import_file_3.read()

#vibo: разбиваем строку по буквам с верхним регистром
import_list_3 = re.findall(r'[A-Z]?[^A-Z]*', import_object_3)
#vibo: удаляем последний элемент списка (почему-то появлялся - '')
import_list_3 = import_list_3[:int(len(import_list_3))-1]

#vibo: импортирируем словарь
periodic_table = json.load(open('periodic_table.json'))

# %%
#vibo: лист из задания, который был в файле
import_list_3
# Out:
# ['Cr',
#  'Co',
#  'Ra',
#  'Li',
#  'Bh',
#  'Mn',
#  'Md',
#  'Sm',
#  'Nh',
#  'Pb',
#  'Ca',
#  'U',
#  'U',
#  'Mo',
#  'Ir',
#  'Po',
#  'Eu',
#  'C',
#  'Pm',
#  'Po',
#  'Rb',
#  'Pu',
#  'Os',
#  'Lr',
#  'Ar',
#  'Cm',
#  'Pd',
#  'Ce',
#  'N',
#  'Bk',
#  'Ba',
#  'La',
#  'Cu',
#  'As',
#  'Cf',
#  'Pr',
#  'Cd',
#  'Ba',
#  'Nd',
#  'Al',
#  'Al',
#  'Ru',
#  'Ba',
#  'Tl',
#  'Fl',
#  'Uue',
#  'Ts',
#  'Rn',
#  'Ce',
#  'Cr',
#  'Hf',
#  'Pm',
#  'La',
#  'Pb',
#  'Md',
#  'Cf',
#  'Br',
#  'Bk',
#  'Pr',
#  'Gd',
#  'Es',
#  'U',
#  'Cf',
#  'Ne',
#  'Mg',
#  'Sm',
#  'La',
#  'Bh',
#  'Lu',
#  'Ds',
#  'Mo',
#  'Sm',
#  'Al',
#  'O',
#  'Pb',
#  'Db',
#  'Cu',
#  'Ce',
#  'Es',
#  'Es',
#  'Xe',
#  'Ca',
#  'Md',
#  'He',
#  'Sb',
#  'Lv',
#  'Th',
#  'At',
#  'F',
#  'Ru',
#  'Nb',
#  'Pr',
#  'Li',
#  'Cu',
#  'La',
#  'Ni',
#  'Yb',
#  'Md',
#  'Cl',
#  'Ar',
#  'Pm',
#  'Ac',
#  'Tm',
#  'Gd',
#  'At',
#  'Lv',
#  'Sr',
#  'Nd',
#  'Sc',
#  'Tm',
#  'F',
#  'Mg',
#  'Uue',
#  'Ts',
#  'Pd',
#  'Br',
#  'Sm',
#  'Ru',
#  'O',
#  'Te',
#  'Ac',
#  'Lu',
#  'Hs',
#  'Tm',
#  'Uue',
#  'Yb',
#  'Mn',
#  'C',
#  'Hf',
#  'Dy',
#  'Pb',
#  'Ra',
#  'Se',
#  'Pm',
#  'Hf',
#  'Al',
#  'K',
#  'N',
#  'Y',
#  'Hg',
#  'Pr',
#  'Xe',
#  'W',
#  'H',
#  'Ts',
#  'At',
#  'Hs',
#  'Ge',
#  'As',
#  'Rf',
#  'Po',
#  'Tl',
#  'S',
#  'Mo',
#  'Lv',
#  'Hg',
#  'Mc',
#  'Ru',
#  'C',
#  'Ts',
#  'Lr',
#  'Hs',
#  'Po',
#  'Rh',
#  'Yb',
#  'As',
#  'Er',
#  'Tm',
#  'I',
#  'Ti',
#  'Al',
#  'Sg',
#  'N',
#  'F',
#  'V',
#  'Np',
#  'Cu',
#  'Cd',
#  'Sm',
#  'At',
#  'Fe',
#  'Nd',
#  'Ga',
#  'F',
#  'Li',
#  'Br',
#  'In',
#  'Bh',
#  'Os',
#  'Eu',
#  'Nb',
#  'Li',
#  'Ir',
#  'Fl',
#  'Mo',
#  'Fl',
#  'Cu',
#  'La',
#  'Mc',
#  'K',
#  'Se',
#  'Ni',
#  'Cd',
#  'Cm',
#  'As',
#  'S',
#  'Se',
#  'Tm',
#  'Fr',
#  'Po',
#  'Ni',
#  'Te',
#  'Sr',
#  'Mo',
#  'Er',
#  'Pt',
#  'No',
#  'V',
#  'In',
#  'Gd',
#  'Tm',
#  'Ti',
#  'Os',
#  'Pr',
#  'Bh',
#  'Cm',
#  'Am',
#  'O',
#  'Sg',
#  'Sr',
#  'Sr',
#  'Te',
#  'Na',
#  'Sc',
#  'Si',
#  'Er',
#  'Rb',
#  'Pr',
#  'Te',
#  'Cl',
#  'Po',
#  'Ar',
#  'Sm',
#  'Ar',
#  'Lu',
#  'Sn',
#  'Sr',
#  'Au',
#  'P',
#  'Hf',
#  'Ta',
#  'Np',
#  'Og',
#  'Ar',
#  'Cn',
#  'Dy',
#  'La',
#  'Sm',
#  'Co',
#  'Sb',
#  'Si',
#  'Bh',
#  'Tb',
#  'Tb',
#  'Cm',
#  'S',
#  'Er',
#  'Yb',
#  'Co',
#  'Bh',
#  'Es',
#  'Ca',
#  'Er',
#  'Ho',
#  'He',
#  'Al',
#  'Ts',
#  'Cl',
#  'Ra',
#  'Be',
#  'Rb',
#  'Re',
#  'Ho',
#  'Tm',
#  'Sn',
#  'Tc',
#  'Gd',
#  'Bk',
#  'Fe',
#  'Np',
#  'Ca',
#  'Ni',
#  'No',
#  'Tl',
#  'Mg',
#  'Mg',
#  'La',
#  'Nb',
#  'Ni',
#  'At',
#  'Mt',
#  'Ra',
#  'Nb',
#  'Og',
#  'Cl',
#  'Ds',
#  'Kr',
#  'He',
#  'Tb',
#  'Ra',
#  'P',
#  'Cd',
#  'N',
#  'Li',
#  'Pd',
#  'Br',
#  'Zn',
#  'Zn',
#  'Bk',
#  'Si',
#  'I',
#  'Ce',
#  'Bi',
#  'Bi',
#  'K',
#  'B',
#  'Er',
#  'Fr',
#  'Bk',
#  'Xe',
#  'Zn',
#  'Gd',
#  'Er',
#  'Ne',
#  'Rg',
#  'Ga',
#  'Rg',
#  'He',
#  'Rg',
#  'Fm',
#  'Cn',
#  'Tl',
#  'Hg',
#  'Ga',
#  'Nb',
#  'Nh',
#  'Pd',
#  'Lr',
#  'K',
#  'Na',
#  'Kr',
#  'Cn',
#  'Am',
#  'Er',
#  'Ge',
#  'Gd',
#  'Th',
#  'Tm',
#  'C',
#  'Se',
#  'Rg',
#  'Bh',
#  'Db',
#  'Dy',
#  'W',
#  'Cf',
#  'Sm',
#  'Fl',
#  'B',
#  'Ne',
#  'O',
#  'Bk',
#  'Pm',
#  'Uue',
#  'Pr',
#  'Cn',
#  'Ce',
#  'Ti',
#  'Bk',
#  'F',
#  'Uue',
#  'Cd',
#  'O',
#  'Yb',
#  'Yb',
#  'Li',
#  'Eu',
#  'Es',
#  'Bk',
#  'Hg',
#  'Gd',
#  'Li',
#  'Mc',
#  'Np',
#  'Y',
#  'Hf',
#  'Cl',
#  'Fe',
#  'Mt',
#  'Ca',
#  'Xe',
#  'Ni',
#  'Er',
#  'Rg',
#  'Ho',
#  'Ni',
#  'Tb',
#  'Ra',
#  'I',
#  'Cu',
#  'Tm',
#  'Mg',
#  'Co',
#  'Mg',
#  'Cd',
#  'Bh',
#  'Ce',
#  'Cn',
#  'Ne',
#  'U',
#  'Ar',
#  'Fr',
#  'V',
#  'Er',
#  'Rh',
#  'Au',
#  'Np',
#  'Np',
#  'Np',
#  'Ge',
#  'Cn',
#  'Lv',
#  'La',
#  'Sr',
#  'Ir',
#  'Lu',
#  'Cf',
#  'Yb',
#  'Fl',
#  'Ac',
#  'U',
#  'Cf',
#  'In',
#  'B',
#  'Sb',
#  'Am',
#  'Sr',
#  'Br',
#  'Co',
#  'V',
#  'Si',
#  'In',
#  'Sm',
#  'Os',
#  'Te',
#  'Pt',
#  'Mo',
#  'Rf',
#  'Zn',
#  'Ta',
#  'H',
#  'Pd',
#  'Se',
#  'Au',
#  'V',
#  'As',
#  'Hg',
#  'Te',
#  'Xe',
#  'Mg',
#  'Nb',
#  'Uue',
#  'Mt',
#  'Y',
#  'Db',
#  'O',
#  'Gd',
#  'Kr',
#  'Xe',
#  'Fm',
#  'F',
#  'Hf',
#  'Rn',
#  'He',
#  'Mo',
#  'Ds',
#  'Cn',
#  'Mt',
#  'Os',
#  'Bi',
#  'Po',
#  'Sr',
#  'N',
#  'Pd',
#  'Rg',
#  'Kr',
#  'K',
#  'Kr',
#  'Hf',
#  'F']

# %%
len(import_list_3)
# Out:
# 500

# %%
#vibo: словарь с заданными названиями химических элементов
periodic_table
# Out:
# {'Ac': 'Актиний',
#  'Ag': 'Серебро',
#  'Al': 'Алюминий',
#  'Am': 'Америций',
#  'Ar': 'Аргон',
#  'As': 'Мышьяк',
#  'At': 'Астат',
#  'Au': 'Золото',
#  'B': 'Бор',
#  'Ba': 'Барий',
#  'Be': 'Бериллий',
#  'Bh': 'Борий',
#  'Bi': 'Висмут',
#  'Bk': 'Берклий',
#  'Br': 'Бром',
#  'C': 'Углерод',
#  'Ca': 'Кальций',
#  'Cd': 'Кадмий',
#  'Ce': 'Церий',
#  'Cf': 'Калифорний',
#  'Cl': 'Хлор',
#  'Cm': 'Кюрий',
#  'Cn': 'Коперниций',
#  'Co': 'Кобальт',
#  'Cr': 'Хром',
#  'Cs': 'Цезий',
#  'Cu': 'Медь',
#  'Db': 'Дубний',
#  'Ds': 'Дармштадтий',
#  'Dy': 'Диспрозий',
#  'Er': 'Эрбий',
#  'Es': 'Эйнштейний',
#  'Eu': 'Европий',
#  'F': 'Фтор',
#  'Fe': 'Железо',
#  'Fl': 'Флеровий',
#  'Fm': 'Фермий',
#  'Fr': 'Франций',
#  'Ga': 'Галий',
#  'Gd': 'Гадолиний',
#  'Ge': 'Германий',
#  'H': 'Водород',
#  'He': 'Гелий',
#  'Hf': 'Гафний',
#  'Hg': 'Ртуть',
#  'Ho': 'Гольмий',
#  'Hs': 'Хассий',
#  'I': 'Йод',
#  'In': 'Индий',
#  'Ir': 'Иридий',
#  'K': 'Калий',
#  'Kr': 'Криптон',
#  'La': 'Лантан',
#  'Li': 'Литий',
#  'Lr': 'Лоуренсий',
#  'Lu': 'Лютеций',
#  'Lv': 'Ливерморий',
#  'Mc': 'Московий',
#  'Md': 'Менделевий',
#  'Mg': 'Магний',
#  'Mn': 'Марганец',
#  'Mo': 'Молибден',
#  'Mt': 'Мейтнерий',
#  'N': 'Азот',
#  'Na': 'Натрий',
#  'Nb': 'Ниобий',
#  'Nd': 'Неодим',
#  'Ne': 'Неон',
#  'Nh': 'Нихоний',
#  'Ni': 'Никель',
#  'No': 'Нобелий',
#  'Np': 'Нептуний',
#  'O': 'Кислород',
#  'Ods': 'Пасхалочка',
#  'Og': 'Оганесон',
#  'Os': 'Осмий',
#  'P': 'Фосфор',
#  'Pa': 'Протактиний',
#  'Pb': 'Свинец',
#  'Pd': 'Палладий',
#  'Pm': 'Прометий',
#  'Po': 'Полоний',
#  'Pr': 'Празеодим',
#  'Pt': 'Платина',
#  'Pu': 'Плутоний',
#  'Ra': 'Радий',
#  'Rb': 'Рубидий',
#  'Re': 'Рений',
#  'Rf': 'Разерфордий',
#  'Rg': 'Ренгений',
#  'Rh': 'Родий',
#  'Rn': 'Радон',
#  'Ru': 'Рутений',
#  'S': 'Сера',
#  'Sb': 'Сурьма',
#  'Sc': 'Скандий',
#  'Se': 'Селен',
#  'Sg': 'Сиборгий',
#  'Si': 'Кремний',
#  'Sm': 'Самарий',
#  'Sn': 'Олово',
#  'Sr': 'Стронций',
#  'Ta': 'Тантал',
#  'Tb': 'Тербий',
#  'Tc': 'Технеций',
#  'Te': 'Теллур',
#  'Th': 'Торий',
#  'Ti': 'Титан',
#  'Tl': 'Таллий',
#  'Tm': 'Тулий',
#  'Ts': 'Теннессин',
#  'U': 'Уран',
#  'Uue': 'Унуненний',
#  'V': 'Ванадий',
#  'W': 'Вольфрам',
#  'Xe': 'Ксенон',
#  'Y': 'Иттрий',
#  'Yb': 'Иттербий',
#  'Zn': 'Цинк',
#  'Zr': 'Цирконий'}

# %%
#vibo: делаем пустой список для накопления результата
result_list = []
#vibo: идем по элементам списка из файла
for element in import_list_3:
    #vibo: иммем один элемент, проходим по ключам словаря
    for key in periodic_table:
        #vibo: если ключ словаря совпадает с элементом списка
        if key == element:
            print(key, ' = ', element, ' = ', periodic_table[key])
            #vibo: добавляем элемент в итоговый лист
            result_list.append(periodic_table[key])
# Out:
# Cr  =  Cr  =  Хром
# Co  =  Co  =  Кобальт
# Ra  =  Ra  =  Радий
# Li  =  Li  =  Литий
# Bh  =  Bh  =  Борий
# Mn  =  Mn  =  Марганец
# Md  =  Md  =  Менделевий
# Sm  =  Sm  =  Самарий
# Nh  =  Nh  =  Нихоний
# Pb  =  Pb  =  Свинец
# Te  =  Te  =  Теллур
# Xe  =  Xe  =  Ксенон
# Mg  =  Mg  =  Магний
# Nb  =  Nb  =  Ниобий
# Uue  =  Uue  =  Унуненний
# Mt  =  Mt  =  Мейтнерий
# Y  =  Y  =  Иттрий
# Db  =  Db  =  Дубний
# O  =  O  =  Кислород
# Gd  =  Gd  =  Гадолиний
# Kr  =  Kr  =  Криптон
# Xe  =  Xe  =  Ксенон
# Fm  =  Fm  =  Фермий
# F  =  F  =  Фтор
# Hf  =  Hf  =  Гафний
# Rn  =  Rn  =  Радон
# He  =  He  =  Гелий
# Mo  =  Mo  =  Молибден
# Ds  =  Ds  =  Дармштадтий
# Cn  =  Cn  =  Коперниций
# Mt  =  Mt  =  Мейтнерий
# Os  =  Os  =  Осмий
# Bi  =  Bi  =  Висмут
# Po  =  Po  =  Полоний
# Sr  =  Sr  =  Стронций
# N  =  N  =  Азот
# Pd  =  Pd  =  Палладий
# Rg  =  Rg  =  Ренгений
# Kr  =  Kr  =  Криптон
# K  =  K  =  Калий
# Kr  =  Kr  =  Криптон
# Hf  =  Hf  =  Гафний
# F  =  F  =  Фтор

# %%
#vibo:
print(result_list)
# Out:
# ['Хром', 'Кобальт', 'Радий', 'Литий', 'Борий', 'Марганец', 'Менделевий', 'Самарий', 'Нихоний', 'Свинец', 'Кальций', 'Уран', 'Уран', 'Молибден', 'Иридий', 'Полоний', 'Европий', 'Углерод', 'Прометий', 'Полоний', 'Рубидий', 'Плутоний', 'Осмий', 'Лоуренсий', 'Аргон', 'Кюрий', 'Палладий', 'Церий', 'Азот', 'Берклий', 'Барий', 'Лантан', 'Медь', 'Мышьяк', 'Калифорний', 'Празеодим', 'Кадмий', 'Барий', 'Неодим', 'Алюминий', 'Алюминий', 'Рутений', 'Барий', 'Таллий', 'Флеровий', 'Унуненний', 'Теннессин', 'Радон', 'Церий', 'Хром', 'Гафний', 'Прометий', 'Лантан', 'Свинец', 'Менделевий', 'Калифорний', 'Бром', 'Берклий', 'Празеодим', 'Гадолиний', 'Эйнштейний', 'Уран', 'Калифорний', 'Неон', 'Магний', 'Самарий', 'Лантан', 'Борий', 'Лютеций', 'Дармштадтий', 'Молибден', 'Самарий', 'Алюминий', 'Кислород', 'Свинец', 'Дубний', 'Медь', 'Церий', 'Эйнштейний', 'Эйнштейний', 'Ксенон', 'Кальций', 'Менделевий', 'Гелий', 'Сурьма', 'Ливерморий', 'Торий', 'Астат', 'Фтор', 'Рутений', 'Ниобий', 'Празеодим', 'Литий', 'Медь', 'Лантан', 'Никель', 'Иттербий', 'Менделевий', 'Хлор', 'Аргон', 'Прометий', 'Актиний', 'Тулий', 'Гадолиний', 'Астат', 'Ливерморий', 'Стронций', 'Неодим', 'Скандий', 'Тулий', 'Фтор', 'Магний', 'Унуненний', 'Теннессин', 'Палладий', 'Бром', 'Самарий', 'Рутений', 'Кислород', 'Теллур', 'Актиний', 'Лютеций', 'Хассий', 'Тулий', 'Унуненний', 'Иттербий', 'Марганец', 'Углерод', 'Гафний', 'Диспрозий', 'Свинец', 'Радий', 'Селен', 'Прометий', 'Гафний', 'Алюминий', 'Калий', 'Азот', 'Иттрий', 'Ртуть', 'Празеодим', 'Ксенон', 'Вольфрам', 'Водород', 'Теннессин', 'Астат', 'Хассий', 'Германий', 'Мышьяк', 'Разерфордий', 'Полоний', 'Таллий', 'Сера', 'Молибден', 'Ливерморий', 'Ртуть', 'Московий', 'Рутений', 'Углерод', 'Теннессин', 'Лоуренсий', 'Хассий', 'Полоний', 'Родий', 'Иттербий', 'Мышьяк', 'Эрбий', 'Тулий', 'Йод', 'Титан', 'Алюминий', 'Сиборгий', 'Азот', 'Фтор', 'Ванадий', 'Нептуний', 'Медь', 'Кадмий', 'Самарий', 'Астат', 'Железо', 'Неодим', 'Галий', 'Фтор', 'Литий', 'Бром', 'Индий', 'Борий', 'Осмий', 'Европий', 'Ниобий', 'Литий', 'Иридий', 'Флеровий', 'Молибден', 'Флеровий', 'Медь', 'Лантан', 'Московий', 'Калий', 'Селен', 'Никель', 'Кадмий', 'Кюрий', 'Мышьяк', 'Сера', 'Селен', 'Тулий', 'Франций', 'Полоний', 'Никель', 'Теллур', 'Стронций', 'Молибден', 'Эрбий', 'Платина', 'Нобелий', 'Ванадий', 'Индий', 'Гадолиний', 'Тулий', 'Титан', 'Осмий', 'Празеодим', 'Борий', 'Кюрий', 'Америций', 'Кислород', 'Сиборгий', 'Стронций', 'Стронций', 'Теллур', 'Натрий', 'Скандий', 'Кремний', 'Эрбий', 'Рубидий', 'Празеодим', 'Теллур', 'Хлор', 'Полоний', 'Аргон', 'Самарий', 'Аргон', 'Лютеций', 'Олово', 'Стронций', 'Золото', 'Фосфор', 'Гафний', 'Тантал', 'Нептуний', 'Оганесон', 'Аргон', 'Коперниций', 'Диспрозий', 'Лантан', 'Самарий', 'Кобальт', 'Сурьма', 'Кремний', 'Борий', 'Тербий', 'Тербий', 'Кюрий', 'Сера', 'Эрбий', 'Иттербий', 'Кобальт', 'Борий', 'Эйнштейний', 'Кальций', 'Эрбий', 'Гольмий', 'Гелий', 'Алюминий', 'Теннессин', 'Хлор', 'Радий', 'Бериллий', 'Рубидий', 'Рений', 'Гольмий', 'Тулий', 'Олово', 'Технеций', 'Гадолиний', 'Берклий', 'Железо', 'Нептуний', 'Кальций', 'Никель', 'Нобелий', 'Таллий', 'Магний', 'Магний', 'Лантан', 'Ниобий', 'Никель', 'Астат', 'Мейтнерий', 'Радий', 'Ниобий', 'Оганесон', 'Хлор', 'Дармштадтий', 'Криптон', 'Гелий', 'Тербий', 'Радий', 'Фосфор', 'Кадмий', 'Азот', 'Литий', 'Палладий', 'Бром', 'Цинк', 'Цинк', 'Берклий', 'Кремний', 'Йод', 'Церий', 'Висмут', 'Висмут', 'Калий', 'Бор', 'Эрбий', 'Франций', 'Берклий', 'Ксенон', 'Цинк', 'Гадолиний', 'Эрбий', 'Неон', 'Ренгений', 'Галий', 'Ренгений', 'Гелий', 'Ренгений', 'Фермий', 'Коперниций', 'Таллий', 'Ртуть', 'Галий', 'Ниобий', 'Нихоний', 'Палладий', 'Лоуренсий', 'Калий', 'Натрий', 'Криптон', 'Коперниций', 'Америций', 'Эрбий', 'Германий', 'Гадолиний', 'Торий', 'Тулий', 'Углерод', 'Селен', 'Ренгений', 'Борий', 'Дубний', 'Диспрозий', 'Вольфрам', 'Калифорний', 'Самарий', 'Флеровий', 'Бор', 'Неон', 'Кислород', 'Берклий', 'Прометий', 'Унуненний', 'Празеодим', 'Коперниций', 'Церий', 'Титан', 'Берклий', 'Фтор', 'Унуне ...

# %%
len(result_list)
# Out:
# 500

# %%
#vibo: преобразуем каждый элемент list в str и склеиваем join
result_str = ''.join([str(_) for _ in result_list])
print(result_str)
# Out:
# ХромКобальтРадийЛитийБорийМарганецМенделевийСамарийНихонийСвинецКальцийУранУранМолибденИридийПолонийЕвропийУглеродПрометийПолонийРубидийПлутонийОсмийЛоуренсийАргонКюрийПалладийЦерийАзотБерклийБарийЛантанМедьМышьякКалифорнийПразеодимКадмийБарийНеодимАлюминийАлюминийРутенийБарийТаллийФлеровийУнуненнийТеннессинРадонЦерийХромГафнийПрометийЛантанСвинецМенделевийКалифорнийБромБерклийПразеодимГадолинийЭйнштейнийУранКалифорнийНеонМагнийСамарийЛантанБорийЛютецийДармштадтийМолибденСамарийАлюминийКислородСвинецДубнийМедьЦерийЭйнштейнийЭйнштейнийКсенонКальцийМенделевийГелийСурьмаЛиверморийТорийАстатФторРутенийНиобийПразеодимЛитийМедьЛантанНикельИттербийМенделевийХлорАргонПрометийАктинийТулийГадолинийАстатЛиверморийСтронцийНеодимСкандийТулийФторМагнийУнуненнийТеннессинПалладийБромСамарийРутенийКислородТеллурАктинийЛютецийХассийТулийУнуненнийИттербийМарганецУглеродГафнийДиспрозийСвинецРадийСеленПрометийГафнийАлюминийКалийАзотИттрийРтутьПразеодимКсенонВольфрамВодородТеннессинАстатХассийГерманийМышьякРазерфордийПолонийТаллийСераМолибденЛиверморийРтутьМосковийРутенийУглеродТеннессинЛоуренсийХассийПолонийРодийИттербийМышьякЭрбийТулийЙодТитанАлюминийСиборгийАзотФторВанадийНептунийМедьКадмийСамарийАстатЖелезоНеодимГалийФторЛитийБромИндийБорийОсмийЕвропийНиобийЛитийИридийФлеровийМолибденФлеровийМедьЛантанМосковийКалийСеленНикельКадмийКюрийМышьякСераСеленТулийФранцийПолонийНикельТеллурСтронцийМолибденЭрбийПлатинаНобелийВанадийИндийГадолинийТулийТитанОсмийПразеодимБорийКюрийАмерицийКислородСиборгийСтронцийСтронцийТеллурНатрийСкандийКремнийЭрбийРубидийПразеодимТеллурХлорПолонийАргонСамарийАргонЛютецийОловоСтронцийЗолотоФосфорГафнийТанталНептунийОганесонАргонКоперницийДиспрозийЛантанСамарийКобальтСурьмаКремнийБорийТербийТербийКюрийСераЭрбийИттербийКобальтБорийЭйнштейнийКальцийЭрбийГольмийГелийАлюминийТеннессинХлорРадийБериллийРубидийРенийГольмийТулийОловоТехнецийГадолинийБерклийЖелезоНептунийКальцийНикельНобелийТаллийМагнийМагнийЛантанНиобийНикельАстатМейтнерийРадийНиобийОганесонХлорДармштадтийКриптонГелийТербийРадийФосфорКадмийАзотЛитийПалладийБромЦинкЦинкБерклийКремнийЙодЦерийВисмутВисмутКалийБорЭрбийФранцийБерклийКсенонЦинкГадолинийЭрбийНеонРенгенийГалийРенгенийГелийРенгенийФермийКоперницийТаллийРтутьГалийНиобийНихонийПалладийЛоуренсийКалийНатрийКриптонКоперницийАмерицийЭрбийГерманийГадолинийТорийТулийУглеродСеленРенгенийБорийДубнийДиспрозийВольфрамКалифорнийСамарийФлеровийБорНеонКислородБерклийПрометийУнуненнийПразеодимКоперницийЦерийТитанБерклийФторУнуненнийКадмийКислородИттербийИттербийЛитийЕвропийЭйнштейнийБерклийРтутьГадолинийЛитийМосковийНептунийИттрийГафнийХлорЖелезоМейтнерийКальцийКсенонНикельЭрбийРенгенийГольмийНикельТербийРадийЙодМедьТулийМагнийКобальтМагнийКадмийБорийЦерийКоперницийНеонУранАргонФранцийВанадийЭрбийРодийЗолотоНептунийНептунийНептунийГерманийКоперницийЛиверморийЛантанСтронцийИридийЛютецийКалифорнийИттербийФлеровийАктинийУранКалифорнийИндийБорСурьмаАмерицийСтронцийБромКобальтВанадийКремнийИндийСамарийОсмийТеллурПлатинаМолибденРазерфордийЦинкТанталВодородПалладийСеленЗолотоВанадийМышьякРтутьТеллурКсенонМагнийНиобийУнуненнийМейтнерийИттрийДубнийКислородГадолинийКриптонКсенонФермийФторГафнийРадонГелийМолибденДармштадтийКоперницийМейтнерийОсмийВисмутПолонийСтронцийАзотПалладийРенгенийКриптонКалийКриптонГафнийФтор

# %%
#vibo: записываем ответ в файл
with open('v_output_file_4.txt', 'w') as f:
    f.write(result_str)

# %% [markdown]
# #### Итоговое решение

# %%
#vibo: загружаем библиотеки
import re
import json

#vibo: читаем данные из заданного файла
import_file_3 = open ('import_file_3.txt', 'r')
import_object_3 = import_file_3.read()

#vibo: разбиваем строку по буквам с верхним регистром
import_list_3 = re.findall(r'[A-Z]?[^A-Z]*', import_object_3)
#vibo: удаляем последний элемент списка (почему-то появлялся - '')
import_list_3 = import_list_3[:int(len(import_list_3))-1]

#vibo: импортирируем словарь
periodic_table = json.load(open('periodic_table.json'))

#vibo: делаем пустой список для накопления результата
result_list = []
#vibo: идем по элементам списка из файла
for element in import_list_3:
    #vibo: иммем один элемент, проходим по ключам словаря
    for key in periodic_table:
        #vibo: если ключ словаря совпадает с элементом списка
        if key == element:
            #vibo: добавляем элемент в итоговый лист
            result_list.append(periodic_table[key])

#vibo: преобразуем каждый элемент list в str и склеиваем join
result_str = ''.join([str(_) for _ in result_list])

#vibo: записываем ответ в файл
with open('v_output_file_3.txt', 'w') as f:
    f.write(result_str)

# %% [markdown]
# ##### Код для ods.ai

# %%
import re
import json

import_file_3 = open ('import_file_3.txt', 'r')
import_object_3 = import_file_3.read()

import_list_3 = re.findall(r'[A-Z]?[^A-Z]*', import_object_3)
import_list_3 = import_list_3[:int(len(import_list_3))-1]

periodic_table = json.load(open('periodic_table.json'))

result_list = []
for element in import_list_3:
    for key in periodic_table:
        if key == element:
            result_list.append(periodic_table[key])

result_str = ''.join([str(_) for _ in result_list])

with open('v_output_file_3.txt', 'w') as f:
    f.write(result_str)
